# %%
from sklearn.datasets import load_boston
boston = load_boston()
dfx = pd.DataFrame(boston.data, columns = boston.feature_names)
dfy = pd.DataFrame(boston.target, columns = ["MEDV"])
df = pd.concat([dfx,dfy], axis = 1)

# %%
dfx
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
dfy
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
# %matplotlib inline
np.random.seed(0)
x = sp.stats.beta(15, 12).rvs(10000)

sns.distplot(x, kde = False, norm_hist = True)
plt.title("Sample histogram according to beta distribution")
plt.show()

# %%
def estimate_beta(x):
    x_bar = x.mean()
    s2 = x.var()
    a = x_bar * (x_bar * (1 - x_bar) / s2 - 1)
    b = (1 - x_bar) * (x_bar * (1 - x_bar) / s2 - 1)
    return a, b

params = estimate_beta(x)
print(params)
# Out:
# (15.346682046700685, 12.2121537049535)

# %%
xx = np.linspace(0, 1, 1000)
sns.distplot(x, kde = False, norm_hist = True)
plt.plot(xx, sp.stats.beta(params[0], params[1]).pdf(xx))
plt.xlim(0,1)
plt.show()

# %%
sns.distplot(x, kde = False, norm_hist = True, fit = sp.stats.beta)
plt.xlim(0,1)
plt.show()

# %%
sns.distplot(dfx, kde = False, norm_hist = True, fit = sp.stats.beta)
plt.show()

# %%
sns.distplot(dfy, kde = False, norm_hist = True, fit = sp.stats.f)
plt.show()

# %%
sns.distplot(df, kde = False, norm_hist = True)
plt.show()

# %%
def likelihood_mu(mu):
    return sp.stats.norm(loc = mu).pdf(0)

mus = np.linspace(-5, 5, 1000)
likelihood_mu = [likelihood_mu(m) for m in mus]

plt.subplot(211)
plt.plot(mus,likelihood_mu)
plt.title("Likelihood fuction $L(\mu, \sigma^2 = 1; x = 0)$")
plt.xlabel("$\mu$")
plt.show()

def likelihood_sigma2(sigma2):
    return sp.stats.norm(scale = np.sqrt(sigma2)).pdf(0)

sigma2s = np.linspace(0.1, 10, 1000)
likelihood_sigma2 = [likelihood_sigma2(s) for s in sigma2s]

plt.subplot(212)
plt.plot(sigma2s, likelihood_sigma2)
plt.title("Likelihood function $L(\mu = 0, \sigma; x = 0)$")
plt.xlabel("$\sigma^2$")
plt.show()

# %%
MU, SIGMA2 = np.meshgrid(mus,sigma2s)
L = np.exp(-MU ** 2 / (2 * SIGMA2)) / np.sqrt(2 * np.pi * SIGMA2)

fig = plt.figure()
ax = fig.gca(projection = '3d')
ax.plot_surface(MU, SIGMA2, L, linewidth = 0.1)
plt.xlabel('$\mu$')
plt.ylabel('$\sigma^2$')
plt.title('Likelihoodfunction $L(\mu, \sigma^2)$')
plt.show()

# %%
mu = np.linspace(-3, 3, 1000)
sigma2 = 1

def likelihood(mu):
    return (2 * np.pi * sigma2) ** (3 / 2) * np.exp(-(3 * mu ** 2 + 4 * mu + 10) / (2 * sigma2))

li = likelihood(mu)

plt.plot(mu, li)
plt.vlines(-2/3, 0, 0.25, linestyles = ":")
plt.xlabel(r"parameter $\mu$")
plt.show()

# %%
xx = np.linspace(0, 1, 1000)
a0, b0 = 1, 1
plt.plot(xx, sp.stats.beta(a0, b0).pdf(xx), c= "r", ls = "--", label = "Prior distribution")
a1, b1 = 6 + 1, 4 + 1
plt.plot(xx, sp.stats.beta(a1, b1).pdf(xx), c= "g", ls = "-", label = "Posterior distribution")
plt.legend()
plt.show()

# %%
mu0 = 0.65
a, b = 1, 1
print("prior estimation : mode = unknown")

xx = np.linspace(0, 1, 1000)
plt.plot(xx, sp.stats.beta(a, b).pdf(xx), ls = ":", label = "prior estimation")

np.random.seed(0)

for i in range(3):
    x = sp.stats.bernoulli(mu0).rvs(50)
    N0, N1 = np.bincount(x, minlength =2)
    a, b, = a + N1, b + N0
    plt.plot(xx, sp.stats.beta(a, b).pdf(xx), ls = "-.", label = "{}st estimation".format(i))
    print("{}st estimation : mode = {:.2f}".format(i, (a - 1) / (a + b - 2)))
    
plt.vlines(x = 0.65, ymin = 0, ymax = 12)
plt.ylim(0, 12)
plt.legend()
plt.show()
# Out:
# prior estimation : mode = unknown
# 0st estimation : mode = 0.64
# 1st estimation : mode = 0.69
# 2st estimation : mode = 0.65

# %%
def plot_dirichlet(alpha, n):

    def project(x):
        n1 = np.array([1, 0, 0])
        n2 = np.array([0, 1, 0])
        n3 = np.array([0, 0, 1])
        n12 = (n1 + n2)/2
        m1 = np.array([1, -1, 0])
        m2 = n3 - n12
        m1 = m1/np.linalg.norm(m1)
        m2 = m2/np.linalg.norm(m2)
        return np.dstack([(x-n12).dot(m1), (x-n12).dot(m2)])[0]

    def project_reverse(x):
        n1 = np.array([1, 0, 0])
        n2 = np.array([0, 1, 0])
        n3 = np.array([0, 0, 1])
        n12 = (n1 + n2)/2
        m1 = np.array([1, -1, 0])
        m2 = n3 - n12
        m1 = m1/np.linalg.norm(m1)
        m2 = m2/np.linalg.norm(m2)
        return x[:, 0][:, np.newaxis] * m1 + x[:, 1][:, np.newaxis] * m2 + n12

    eps = np.finfo(float).eps * 10
    X = project([[1-eps, 0, 0], [0, 1-eps, 0], [0, 0, 1-eps]])

    import matplotlib.tri as mtri

    triang = mtri.Triangulation(X[:, 0], X[:, 1], [[0, 1, 2]])
    refiner = mtri.UniformTriRefiner(triang)
    triang2 = refiner.refine_triangulation(subdiv=6)
    XYZ = project_reverse(
        np.dstack([triang2.x, triang2.y, 1-triang2.x-triang2.y])[0])

    pdf = sp.stats.dirichlet(alpha).pdf(XYZ.T)
    plt.tricontourf(triang2, pdf, cmap=plt.cm.bone_r)
    plt.axis("equal")
    plt.title("정규분포 확률변수의 모수를 베이즈 추정법으로 추정한 결과: {} 추정".format(n))
    plt.show()

mu0 = np.array([0.3, 0.5, 0.2])

np.random.seed(0)

# %%
a0 = np.ones(3)
plot_dirichlet(a0, "Initial")

# %%
x1 = np.random.choice(3, 50, p = mu0)
N1 = np.bincount(x1, minlength = 3)
a1 = a0 + N1
print("종류별 붓꽃의 수 ={}".format(N1))
print("1차 추정 하이퍼모수:", (a1 - 1)/(a1.sum() - 3))
plot_dirichlet(a1, "Fist")
# Out:
# 종류별 붓꽃의 수 =[ 9 29 12]
# 1차 추정 하이퍼모수: [0.18 0.58 0.24]

# %%
x2 = np.random.choice(3, 50, p = mu0)
N2 = np.bincount(x2, minlength = 3)
a2 = a1 + N2 
print(N2)
plot_dirichlet(a2, "Second")
# Out:
# [12 26 12]

# %%
mu, sigma2 = 2, 4
mu0, sigma20 = 0, 1
xx = np.linspace(1.8, 2.2, 1000)
np.random.seed(1)
N = 100
ls = [":", "-.", "--", "-", "-", "-", "-", "-"]
for i in range(8):
    x = sp.stats.norm(mu).rvs(N)
    mu0 = sigma2 / (N *sigma20 + sigma2) * mu0 + \
    (N*sigma20)/(N * sigma20 + sigma2) * x.mean()
    sigma20 = 1 / (1 / sigma20 + N / sigma2)
    plt.plot(xx, sp.stats.norm(mu0, sigma20).pdf(xx), ls = ls[i], label = "{}st estimation".format(i))
plt.legend()
plt.show()

# %%
xx1 = np.linspace(-4, 4, 100)

black = {"facecolor" : "black"}
plt.figure(figsize = (8, 4))

plt.subplot(121)
plt.title("In case of T of high probability")
plt.plot(xx1, sp.stats.norm.pdf(xx1))
plt.plot(0.5, 0, "ro")
plt.annotate('actuacl  t value', xy = (0.5, 0.01), xytext = (0.85, 0.1), arrowprops = black)

plt.subplot(122)
plt.title("In case of T of low probability")
plt.plot(xx1, sp.stats.norm.pdf(xx1))
plt.plot(2.2, 0, "ro")
plt.annotate('actuacl  t value $t_0$', xy = (2.2, 0.01), xytext = (0.85, 0.1), arrowprops = black)

plt.suptitle("Distribution of t statistics and actual t value", y = 1.05)
plt.tight_layout()
plt.show()

# %%
N = 20
mu = 0.5
rv = sp.stats.binom(N, mu)

xx = np.arange(N + 1)

plt.subplot(211)
plt.stem(xx, rv.pmf(xx))
plt.ylabel("pmf")
plt.title("PMF of T(N=20)")
black = {"facecolor": "black"}
plt.annotate('t = 11', xy = (11, 0.02), xytext = (11, 0.1), arrowprops = black)

plt.subplot(212)
plt.stem(xx, rv.cdf(xx))
plt.ylabel("cdf")
plt.title("CDF of T(N=20)")

plt.tight_layout()
plt.show()

# %%
2 * (1 - rv.cdf(11 -1 ))
# Out:
# 0.8238029479980464

# %%
1 - rv.cdf(11 -1 )
# Out:
# 0.4119014739990232

# %%
x = np.array([-0.025, -0.05, 0.043, -0.037, -0.056])
t = x.mean() / x.std(ddof = 1) * np.sqrt(len(x))
t
# Out:
# -1.4025921414082105

# %%
sp.stats.t(df=4).cdf(t)
# Out:
# 0.11669216509589829

# %%
rv = sp.stats.norm()

xx = np.linspace(-4, 4, 100)

plt.subplot(211)
plt.plot(xx, rv.pdf(xx))
plt.ylabel("pdf")

plt.show()

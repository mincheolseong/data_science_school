# %%
import matplotlib as mpl
import matplotlib.pylab as plt
import matplotlib.font_manager as fm
path = 'C:\\Users\\82104\\Downloads\\NanumBarunGothic.ttf'
fontprop = fm.FontProperties(fname = path, size = 18)

# %%
# %matplotlib inline

# %%
plt.title("Plot")
plt.plot([1, 4, 9, 16])
plt.show()

# %%
plt.title("x ticks")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.show()

# %%
# 폰트 설정
mpl.rc('font', family='NanumGothic')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %%
plt.title('한글 제목', fontproperties = fontprop)
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel("엑스축 라벨", fontproperties = fontprop)
plt.ylabel("와이축 라벨", fontproperties = fontprop)
plt.show()

# %%
font1 = {'family': 'NanumMyeongjo', 'size': 24, 
         'color':  'black'}
font2 = {'family': 'NanumBarunpen', 'size': 18, 'weight': 'bold',
         'color':  'darkred'}
font3 = {'family': 'NanumBarunGothic', 'size': 12, 'weight': 'light',
         'color':  'blue'}

plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.title('한글 제목', fontdict=font1, fontproperties = fontprop)
plt.xlabel('엑스 축', fontdict=font2, fontproperties = fontprop)
plt.ylabel('와이 축', fontdict=font3, fontproperties = fontprop)
plt.show()

# %%
#스타일 지정
plt.title("'rs--' 스타일의 plot", fontproperties = fontprop)
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rs--')#color, marker, line style 순
plt.show()

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],c="y", lw = 5,
        LS = "--", marker = "o", ms = 15, mec = "g", mew = 5, mfc = "r")
plt.title("스타일 적용 예", fontproperties = fontprop)
plt.show()

# %%
#그림 범위 지정 by rendering 'xlim', 'ylim'
plt.title("x축, y축 범위 설정", fontproperties = fontprop)
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
        c = "b", lw = 5, ls = "--", marker = "o", ms = 15, mec = "g",
        mew = 5, mfc = "r")
plt.xlim(0,50)
plt.ylim(-10,30)
plt.show()

# %%
#틱 설정
X = np.linspace(-np.pi, np.pi, 256) #np.pi는 파이3.14...의미
C = np.cos(X)
plt.title("x축과 y축의 tick label 설정", fontproperties = fontprop)
plt.plot(X,C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi])
plt.yticks([-1, 0, +1])
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256) #np.pi는 파이3.14...의미
C = np.cos(X)
plt.title("LaTeX, 문자열로 tick label 정의", fontproperties = fontprop)
plt.plot(X,C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$']) #LaTeX 수학 문자식
plt.yticks([-1, 0, +1], ["Low", "Zero", "High"])
plt.show()

# %%
#그리드 설정
X = np.linspace(-np.pi, np.pi, 256) #np.pi는 파이3.14...의미
C = np.cos(X)
plt.title("Grid 제거", fontproperties = fontprop)
plt.plot(X,C)
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$']) #LaTeX 수학 문자식
plt.yticks([-1, 0, +1], ["Low", "Zero", "High"])
plt.grid(False) #Grid 제거하기
plt.show()

# %%
#여러개의 선을 그리기
t = np.arange(0., 5., 0.2)
plt.title("라인 플롯에서 여러개의 선 그리기", fontproperties = fontprop)
plt.plot(t, t, 'r--', t, 0.5 * t **2, 'bs:', t, 0.2 * t **3, 'g^-')
plt.show()
#여러개 할때는 x데이터나 스타일 문자열 생략 불가

# %%
#겹쳐그리기 by rendering multiple plot
plt.title("복수의 plot 명령을 한 그림에서 표현", fontproperties = fontprop)
plt.plot([1, 4, 9, 16],
        c = "b",lw = 5, ls = "--", marker = "o",
         ms = 15, mec = "g", mew = 5, mfc = "r")
plt.plot([9, 16, 4, 1],
        c = "k",lw = 3, ls = ":", marker = "s",
         ms = 10, mec = "m", mew = 5, mfc = "c")
plt.show()

# %%
#범레legend표시
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend를 표시한 플롯", fontproperties = fontprop)
plt.plot(X, C, ls="--", label="cosine")
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc=2)
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label="cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.show()

# %%
#연습 문제 1
X = np.linspace(-10, 10)
C, S, T = np.cos(X), np.sin(X), np.tan(X)
plt.plot(X, C, label="cosine",
        c = "c",lw = 2, ls = "--", marker = "o",
         ms = 8, mec = "g", mew = 2, mfc = "r")
plt.plot(X, S, label="sine",
        c = "b",lw = 4, ls = "-", marker = "s",
         ms = 10, mec = "k", mew = 4, mfc = "w")
plt.plot(X, T, label="tan",
        c = "y",lw = 6, ls = "-", marker = "p",
         ms = 12, mec = "r", mew = 3 , mfc = "m")
plt.xlabel("x_label")
plt.ylabel("y_label")
plt.title("Exercise 1")
plt.xlim(-5,5)
plt.ylim(-8,8)
plt.legend(loc=4)
plt.show()

# %%
#그림의 구조
np.random.seed(0)
f1 = plt.figure(figsize = (10, 2))
plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %%
f1 = plt.figure(1)
plt.title("현재의 Figure 객체", fontproperties = fontprop)
plt.plot([1, 2, 3, 4], 'ro:')

f2 = plt.gcf() # 현재 사용하고 잇는 Figure 객체 얻기
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(432x288) 2104250831752
# Figure(432x288) 2104250831752

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)
#subplot 명령은 행렬로 인식 즉, (2, 1, 1)이면 2X1행렬이고 1st에 plotting한다고 인식
ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout() #플롯간의 간격 자동 맞춤
plt.show()
# Out:
# AxesSubplot(0.125,0.536818;0.775x0.343182)
# AxesSubplot(0.125,0.125;0.775x0.343182)

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()

# %%
#subplots명령으로 복수 axes객체 동시 생성 가능
fig, axes = plt.subplots(2, 2)

#이때는 2차원 ndarray 형태로 axex객체 반환
np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")

axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")

axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")

axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %%
#연습 문제 2
np.random.seed(0)
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)
x3 = np.linspace(0.0, 5.0)
y3 = np.cos(2 * np.pi * x3) * np.exp(+x3)

plt.subplot(221)
plt.plot(np.random.rand(10))
plt.xlabel('x_label')
plt.ylabel('y_label')
plt.title("np.random.rand(10)")

plt.subplot(222)
plt.plot(x1, y1, 'yo-')
plt.xlabel('x_label')
plt.ylabel('y_label')
plt.title("np.cos(2 * np.pi * x1) * np.exp(-x1)")

plt.subplot(223)
plt.plot(x2, y2, 'ys--')
plt.xlabel('x_label')
plt.ylabel('y_label')
plt.title("np.cos(2 * np.pi * x2)")

plt.subplot(224)
plt.plot(x3, y3, 'k^:')
plt.xlabel('x_label')
plt.ylabel('y_label')
plt.title("y3 = np.cos(2 * np.pi * x3) * np.exp(+1)")

plt.tight_layout()
plt.show()

# %%
#Axis 객체와 축
#twinx 명령으로 복수의 y축을 가진 플롯을 만들 수 있음
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("2개의 y축 한 figure에서 사용하기", fontproperties = fontprop)
ax0.plot([10, 5, 2, 9, 7], 'r-', label = "y0")
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g:', label = "y1")
ax1.set_ylabel("y1")
ax1.grid()
ax0.set_xlabel("공유되는 x축", fontproperties = fontprop)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.ticker import EngFormatter

prng = np.random.RandomState(123)

fig, ax = plt.subplots()
ax.set_xscale('log')
formatter = EngFormatter(unit='Hz')
ax.xaxis.set_major_formatter(formatter)

xs = np.logspace(1, 9, 100)
ys = (0.8 + 0.4 * prng.uniform(size=100)) * np.log10(xs)**2
ax.plot(xs, ys)

plt.show()

# %%
import matplotlib.pyplot as plt
from numpy.random import rand


fig, ax = plt.subplots()
for color in ['red', 'green', 'blue']:
    n = 750
    x, y = rand(2, n)
    scale = 100.0 * rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.grid(True)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

# fake data
np.random.seed(937)
data = np.random.lognormal(size=(37, 4), mean=1.5, sigma=1.75)
labels = list('ABCD')

# compute the boxplot stats
stats = cbook.boxplot_stats(data, labels=labels, bootstrap=10000)
# After we've computed the stats, we can go through and change anything.
# Just to prove it, I'll set the median of each set to the median of all
# the data, and double the means
for n in range(len(stats)):
    stats[n]['med'] = np.median(data)
    stats[n]['mean'] *= 2

print(stats[0].keys())

fs = 10  # fontsize

# demonstrate how to toggle the display of different elements:
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(6, 6), sharey=True)
axes[0, 0].bxp(stats)
axes[0, 0].set_title('Default', fontsize=fs)

axes[0, 1].bxp(stats, showmeans=True)
axes[0, 1].set_title('showmeans=True', fontsize=fs)

axes[0, 2].bxp(stats, showmeans=True, meanline=True)
axes[0, 2].set_title('showmeans=True,\nmeanline=True', fontsize=fs)

axes[1, 0].bxp(stats, showbox=False, showcaps=False)
tufte_title = 'Tufte Style\n(showbox=False,\nshowcaps=False)'
axes[1, 0].set_title(tufte_title, fontsize=fs)

axes[1, 1].bxp(stats, shownotches=True)
axes[1, 1].set_title('notch=True', fontsize=fs)

axes[1, 2].bxp(stats, showfliers=False)
axes[1, 2].set_title('showfliers=False', fontsize=fs)

for ax in axes.flatten():
    ax.set_yscale('log')
    ax.set_yticklabels([])

fig.subplots_adjust(hspace=0.4)
plt.show()

# demonstrate how to customize the display different elements:
boxprops = dict(linestyle='--', linewidth=3, color='darkgoldenrod')
flierprops = dict(marker='o', markerfacecolor='green', markersize=12,
                  linestyle='none')
medianprops = dict(linestyle='-.', linewidth=2.5, color='firebrick')
meanpointprops = dict(marker='D', markeredgecolor='black',
                      markerfacecolor='firebrick')
meanlineprops = dict(linestyle='--', linewidth=2.5, color='purple')

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(6, 6), sharey=True)
axes[0, 0].bxp(stats, boxprops=boxprops)
axes[0, 0].set_title('Custom boxprops', fontsize=fs)

axes[0, 1].bxp(stats, flierprops=flierprops, medianprops=medianprops)
axes[0, 1].set_title('Custom medianprops\nand flierprops', fontsize=fs)

axes[1, 0].bxp(stats, meanprops=meanpointprops, meanline=False,
               showmeans=True)
axes[1, 0].set_title('Custom mean\nas point', fontsize=fs)

axes[1, 1].bxp(stats, meanprops=meanlineprops, meanline=True,
               showmeans=True)
axes[1, 1].set_title('Custom mean\nas line', fontsize=fs)

for ax in axes.flatten():
    ax.set_yscale('log')
    ax.set_yticklabels([])

fig.suptitle("I never said they'd be pretty")
fig.subplots_adjust(hspace=0.4)
plt.show()
# Out:
# dict_keys(['label', 'mean', 'iqr', 'cilo', 'cihi', 'whishi', 'whislo', 'fliers', 'q1', 'med', 'q3'])
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
